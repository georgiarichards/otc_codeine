# %% [markdown]
# # This notebook graphs the sales and expenditure data of OTC codeine for 31 countries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
 
#and make the plots appear in the notebook
# %matplotlib inline

# %% [markdown]
# # Import data

# %%
df1 = pd.read_csv("/Users/georgiarichards/Desktop/Python/OTC/otc_sales_long2.csv")
df1
# Out:
#           Country      Country2  order  year      countpop      costpop  \
# 0    South Africa  South Africa      1  2017  33833.098000  1603.809100
# 1    South Africa  South Africa      1  2018  37775.301000  1637.599900
# 2    South Africa  South Africa      1  2016  30976.785000  1348.794400
# 3    South Africa  South Africa      1  2015  31312.934000  1050.480700
# 4    South Africa  South Africa      1  2013  29156.277000  1113.423000
# 5    South Africa  South Africa      1  2014  30092.656000  1085.042600
# 6         Ireland       Ireland      2  2015  26531.701000  5289.811500
# 7         Ireland       Ireland      2  2018  22860.332000  6636.214800
# 8         Ireland       Ireland      2  2014  23344.576000  5410.130900
# 9         Ireland       Ireland      2  2017  23561.025000  6277.884300
# 10        Ireland       Ireland      2  2013  21192.002000  5295.874000
# 11        Ireland       Ireland      2  2016  28140.941000  6436.929700
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 29 columns):
# Country           186 non-null object
# year              186 non-null int64
# countpop          186 non-null float64
# costpop           186 non-null float64
# countpopcach      6 non-null float64
# costpopcach       6 non-null float64
# countpopcaps      66 non-null float64
# costpopcap        66 non-null float64
# countpopcotabs    54 non-null float64
# costpopcotabs     54 non-null float64
# countpopdrops     24 non-null float64
# costpopdrops      24 non-null float64
# countpopgran      6 non-null float64
# costpopgran       6 non-null float64
# countpopliq       54 non-null float64
# costpopliq        54 non-null float64
# countpoploz       36 non-null float64
# costpoploz        36 non-null float64
# countpoppow       30 non-null float64
# costpoppow        30 non-null float64
# countpopsoltab    60 non-null float64
# costpopsoltab     66 non-null float64
# ...

# %%
df1.describe()
# Out:
#               year      countpop      costpop  countpopcach  costpopcach  \
# count   186.000000    186.000000   186.000000      6.000000     6.000000
# mean   2015.500000   4979.616647   552.453274      0.000657     0.000149
# std       1.712435   7868.064797  1091.486270      0.001291     0.000258
# min    2013.000000      0.000000     0.000000      0.000000     0.000000
# 25%    2014.000000     24.492521     2.085422      0.000000     0.000000
# 50%    2015.500000   1295.919250   156.643250      0.000000     0.000000
# 75%    2017.000000   6907.005975   676.024248      0.000535     0.000201
# max    2018.000000  37775.301000  6636.214800      0.003226     0.000627
#
#        countpopcaps  costpopcap  countpopcotabs  costpopcotabs  countpopdrops  \
# count     66.000000   66.000000       54.000000      54.000000      24.000000
# mean     303.410750   77.292219     1064.384128     328.464014     329.561507
# ...

# %% [markdown]
# # Graphing data

# %%
# this code increases the size of the figures  
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# # COUNTS - all items sold

# %%
# this graphs the total number of items sold in all 31 countries 
fig1 = sns.lineplot(data=df1, 
                    x='year', y='countpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of items per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig1.png')
fig1

# %%
# Now I am deleting/dropping countries ranked 20-31 in sales to 
# graph the top 10 countries for sales 
df2 = df1 
df2 = df2.set_index("Country2")
df2 = df2.drop("USA")
df2 = df2.drop("Spain")
df2 = df2.drop("Brazil")
df2 = df2.drop("Italy")
df2 = df2.drop("Portugal")
df2 = df2.drop("Argentina")
df2 = df2.drop("Germany")
df2 = df2.drop("Thailand")
df2 = df2.drop("Greece")
df2 = df2.drop("Russia")
df2 = df2.drop("Canada")
df2 = df2.drop("Mexico")
df2 = df2.drop("Belgium")
df2 = df2.drop("Lithuania")
df2 = df2.drop("Slovakia")
df2 = df2.drop("Slovenia")
df2 = df2.drop("Bulgaria")
df2 = df2.drop("Netherlands")
df2 = df2.drop("Romania")
df2 = df2.drop("Finland")
df2 = df2.drop("Switzerland")
df2

# %%
# graphing the top 10 countries for volume sales [all counts] of OTC codeine 
fig2 = sns.lineplot(data=df2, 
                    x='year', y='countpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of items per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig2.png')
fig2

# %%
# Now I drop countries ranked 1-10 & 21-31 to graph countries ranked 11-20 for volume sales 
df3 = df1 
df3 = df3.set_index("Country2")
df3
# Out:
#                    Country  order  year      countpop      costpop  \
# Country2
# South Africa  South Africa      1  2017  33833.098000  1603.809100
# South Africa  South Africa      1  2018  37775.301000  1637.599900
# South Africa  South Africa      1  2016  30976.785000  1348.794400
# South Africa  South Africa      1  2015  31312.934000  1050.480700
# South Africa  South Africa      1  2013  29156.277000  1113.423000
# South Africa  South Africa      1  2014  30092.656000  1085.042600
# Ireland            Ireland      2  2015  26531.701000  5289.811500
# Ireland            Ireland      2  2018  22860.332000  6636.214800
# Ireland            Ireland      2  2014  23344.576000  5410.130900
# Ireland            Ireland      2  2017  23561.025000  6277.884300
# Ireland            Ireland      2  2013  21192.002000  5295.874000
# Ireland            Ireland      2  2016  28140.941000  6436.929700
# France              France      3  2018    312.783360    31.059135
# ...

# %%
df3 = df3.drop("South Africa")
df3 = df3.drop("Ireland")
df3 = df3.drop("Latvia")
df3 = df3.drop("Japan")
df3 = df3.drop("Poland")
df3 = df3.drop("Estonia")
df3 = df3.drop("France")
df3 = df3.drop("UK")
df3 = df3.drop("Serbia")
df3 = df3.drop("Croatia")
df3 = df3.drop("Spain")
df3 = df3.drop("Brazil")
df3 = df3.drop("Italy")
df3 = df3.drop("Portugal")
df3 = df3.drop("Argentina")
df3 = df3.drop("Germany")
df3 = df3.drop("Thailand")
df3 = df3.drop("Canada")
df3 = df3.drop("Russia")
df3 = df3.drop("USA")
df3 = df3.drop("Greece")
df3

# %%
# graphing volume sales [all counts] for countries ranked 11-20
fig3 = sns.lineplot(data=df3, 
                    x='year', y='countpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of items per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig3.png')
fig3

# %%
# delete rows to create new graph with countries selling the least otc codeine
df4 = df1 
df4 = df4.set_index("Country2")
df4
# Out:
#                    Country  order  year      countpop      costpop  \
# Country2
# South Africa  South Africa      1  2017  33833.098000  1603.809100
# South Africa  South Africa      1  2018  37775.301000  1637.599900
# South Africa  South Africa      1  2016  30976.785000  1348.794400
# South Africa  South Africa      1  2015  31312.934000  1050.480700
# South Africa  South Africa      1  2013  29156.277000  1113.423000
# South Africa  South Africa      1  2014  30092.656000  1085.042600
# Ireland            Ireland      2  2015  26531.701000  5289.811500
# Ireland            Ireland      2  2018  22860.332000  6636.214800
# Ireland            Ireland      2  2014  23344.576000  5410.130900
# Ireland            Ireland      2  2017  23561.025000  6277.884300
# Ireland            Ireland      2  2013  21192.002000  5295.874000
# Ireland            Ireland      2  2016  28140.941000  6436.929700
# France              France      3  2018    312.783360    31.059135
# ...

# %%
df4 = df4.drop("South Africa")
df4 = df4.drop("Ireland")
df4 = df4.drop("France")
df4 = df4.drop("Latvia")
df4 = df4.drop("UK")
df4 = df4.drop("Japan")
df4 = df4.drop("Serbia")
df4 = df4.drop("Poland")
df4 = df4.drop("Estonia")
df4 = df4.drop("Croatia")
df4 = df4.drop("Switzerland")
df4 = df4.drop("Finland")
df4 = df4.drop("Romania")
df4 = df4.drop("Netherlands")
df4 = df4.drop("Bulgaria")
df4 = df4.drop("Slovenia")
df4 = df4.drop("Slovakia")
df4 = df4.drop("Lithuania")
df4 = df4.drop("Belgium")
df4 = df4.drop("Mexico")
df4
# Out:
#              Country  order  year    countpop    costpop  countpopcach  \
# Country2
# Canada        Canada     21  2013  162.050490  16.989761           NaN
# Canada        Canada     21  2014  129.219850  10.700915           NaN
# Canada        Canada     21  2015  108.180540   7.090487           NaN
# Canada        Canada     21  2017   83.843773   2.191262           NaN
# Canada        Canada     21  2018  177.443510   3.917128           NaN
# Canada        Canada     21  2016   63.450363   2.566556           NaN
# Russia        Russia     22  2018  112.339840  19.708704           NaN
# Russia        Russia     22  2014   72.328926  12.991123           NaN
# Russia        Russia     22  2017  127.697620  25.951118           NaN
# Russia        Russia     22  2013   24.025211   4.483094           NaN
# Russia        Russia     22  2016  123.162060  24.062834           NaN
# Russia        Russia     22  2015  118.626990  18.026575           NaN
# ...

# %%
# graphing volume sales [all counts] for countries ranked 21-31 
fig4 = sns.lineplot(data=df4, 
                    x='year', y='countpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of items per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig4.png')
fig4

# %% [markdown]
# # Public expenditure

# %%
dfexpend = pd.read_csv("/Users/georgiarichards/Desktop/Python/OTC/otc_expend.csv")
dfexpend
# Out:
#           Country      Country2  order  order_expend  year      countpop  \
# 0         Ireland       Ireland     13             1  2016  28140.941000
# 1         Ireland       Ireland     13             1  2013  21192.002000
# 2         Ireland       Ireland     13             1  2015  26531.701000
# 3         Ireland       Ireland     13             1  2014  23344.576000
# 4         Ireland       Ireland     13             1  2017  23561.025000
# 5         Ireland       Ireland     13             1  2018  22860.332000
# 6              UK            UK      8             2  2018  11156.975000
# 7              UK            UK      8             2  2014  11618.781000
# 8              UK            UK      8             2  2017  11533.179000
# 9              UK            UK      8             2  2016  11958.910000
# 10             UK            UK      8             2  2015  11893.599000
# 11             UK            UK      8             2  2013  12047.682000
# ...

# %%
# this graphs total public expenditure in all 31 countries 
fig5 = sns.lineplot(data=dfexpend, 
                    x='year', y='costpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("Public expenditure (£) per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig5.png')
fig5

# %%
dfexpend2 = dfexpend 
dfexpend2 = dfexpend2.set_index("Country2")
dfexpend2
# Out:
#                    Country  order  order_expend  year      countpop  \
# Country2
# Ireland            Ireland     13             1  2016  28140.941000
# Ireland            Ireland     13             1  2013  21192.002000
# Ireland            Ireland     13             1  2015  26531.701000
# Ireland            Ireland     13             1  2014  23344.576000
# Ireland            Ireland     13             1  2017  23561.025000
# Ireland            Ireland     13             1  2018  22860.332000
# UK                      UK      8             2  2018  11156.975000
# UK                      UK      8             2  2014  11618.781000
# UK                      UK      8             2  2017  11533.179000
# UK                      UK      8             2  2016  11958.910000
# UK                      UK      8             2  2015  11893.599000
# UK                      UK      8             2  2013  12047.682000
# South Africa  South Africa      1             3  2013  29156.277000
# ...

# %%
# drop countries ranked 11-31 to view the top 10 spending countries 
dfexpend2 = dfexpend2.drop("Poland")
dfexpend2 = dfexpend2.drop("Romania")
dfexpend2 = dfexpend2.drop("Bulgaria")
dfexpend2 = dfexpend2.drop("Slovakia")
dfexpend2 = dfexpend2.drop("Slovenia")
dfexpend2 = dfexpend2.drop("Lithuania")
dfexpend2 = dfexpend2.drop("Netherlands")
dfexpend2 = dfexpend2.drop("Finland")
dfexpend2 = dfexpend2.drop("Belgium")
dfexpend2 = dfexpend2.drop("Russia")
dfexpend2 = dfexpend2.drop("Mexico")
dfexpend2 = dfexpend2.drop("Canada")
dfexpend2 = dfexpend2.drop("USA")
dfexpend2 = dfexpend2.drop("Greece")
dfexpend2 = dfexpend2.drop("Germany")
dfexpend2 = dfexpend2.drop("Thailand")
dfexpend2 = dfexpend2.drop("Argentina")
dfexpend2 = dfexpend2.drop("Italy")
dfexpend2 = dfexpend2.drop("Portugal")
dfexpend2 = dfexpend2.drop("Spain")
dfexpend2 = dfexpend2.drop("Brazil")
dfexpend2
# Out:
#                    Country  order  order_expend  year     countpop  \
# Country2
# Ireland            Ireland     13             1  2016  28140.94100
# Ireland            Ireland     13             1  2013  21192.00200
# Ireland            Ireland     13             1  2015  26531.70100
# Ireland            Ireland     13             1  2014  23344.57600
# Ireland            Ireland     13             1  2017  23561.02500
# Ireland            Ireland     13             1  2018  22860.33200
# UK                      UK      8             2  2018  11156.97500
# UK                      UK      8             2  2014  11618.78100
# UK                      UK      8             2  2017  11533.17900
# UK                      UK      8             2  2016  11958.91000
# UK                      UK      8             2  2015  11893.59900
# UK                      UK      8             2  2013  12047.68200
# South Africa  South Africa      1             3  2013  29156.27700
# ...

# %%
# this graphs the public expenditure in countries ranked 12-31  
fig6 = sns.lineplot(data=dfexpend2, 
                    x='year', y='costpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("Public expenditure (£) per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig6.png')
fig6

# %%
# removing Ireland to see spread of other countries in top 10 
dfexpend2 = dfexpend2.drop("Ireland")
fig7 = sns.lineplot(data=dfexpend2, 
                    x='year', y='costpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("Public expenditure (£) per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
fig7

# %%
dfexpend3 = dfexpend 
dfexpend3 = dfexpend3.set_index("Country2")
dfexpend3
# Out:
#                    Country  order  order_expend  year      countpop  \
# Country2
# Ireland            Ireland     13             1  2016  28140.941000
# Ireland            Ireland     13             1  2013  21192.002000
# Ireland            Ireland     13             1  2015  26531.701000
# Ireland            Ireland     13             1  2014  23344.576000
# Ireland            Ireland     13             1  2017  23561.025000
# Ireland            Ireland     13             1  2018  22860.332000
# UK                      UK      8             2  2018  11156.975000
# UK                      UK      8             2  2014  11618.781000
# UK                      UK      8             2  2017  11533.179000
# UK                      UK      8             2  2016  11958.910000
# UK                      UK      8             2  2015  11893.599000
# UK                      UK      8             2  2013  12047.682000
# South Africa  South Africa      1             3  2013  29156.277000
# ...

# %%
# dropping top 10 & bottom 11 to visualise expenditure in middle ranking countries 
dfexpend3 = dfexpend3.drop("Ireland")
dfexpend3 = dfexpend3.drop("UK")
dfexpend3 = dfexpend3.drop("South Africa")
dfexpend3 = dfexpend3.drop("Japan")
dfexpend3 = dfexpend3.drop("Estonia")
dfexpend3 = dfexpend3.drop("Croatia")
dfexpend3 = dfexpend3.drop("France")
dfexpend3 = dfexpend3.drop("Latvia")
dfexpend3 = dfexpend3.drop("Serbia")
dfexpend3 = dfexpend3.drop("Switzerland")
dfexpend3 = dfexpend3.drop("Mexico")
dfexpend3 = dfexpend3.drop("Canada")
dfexpend3 = dfexpend3.drop("USA")
dfexpend3 = dfexpend3.drop("Greece")
dfexpend3 = dfexpend3.drop("Germany")
dfexpend3 = dfexpend3.drop("Thailand")
dfexpend3 = dfexpend3.drop("Argentina")
dfexpend3 = dfexpend3.drop("Italy")
dfexpend3 = dfexpend3.drop("Portugal")
dfexpend3 = dfexpend3.drop("Spain")
dfexpend3 = dfexpend3.drop("Brazil")
dfexpend3
# Out:
#                  Country  order  order_expend  year     countpop     costpop  \
# Country2
# Poland            Poland     10            11  2016  6973.981900  515.154110
# Poland            Poland     10            11  2015  7195.653300  422.071230
# Poland            Poland     10            11  2017  7493.152800  592.961610
# Poland            Poland     10            11  2014  7178.462900  428.912750
# Poland            Poland     10            11  2018  6893.248500  593.363830
# Poland            Poland     10            11  2013  5775.126500  391.922550
# Romania          Romania      7            12  2018  3150.741900  429.409640
# Romania          Romania      7            12  2017  2899.385500  374.158630
# Romania          Romania      7            12  2015  2982.739300  279.837770
# Romania          Romania      7            12  2013  2860.596700  273.357700
# Romania          Romania      7            12  2014  3067.204100  281.015780
# ...

# %%
# this graphs the public expenditure in countries ranked 12-31  
fig7 = sns.lineplot(data=dfexpend3, 
                    x='year', y='costpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("Public expenditure (£) per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig7.png')
fig7

# %%
dfexpend4 = dfexpend 
dfexpend4 = dfexpend4.set_index("Country2")
dfexpend4
# Out:
#                    Country  order  order_expend  year      countpop  \
# Country2
# Ireland            Ireland     13             1  2016  28140.941000
# Ireland            Ireland     13             1  2013  21192.002000
# Ireland            Ireland     13             1  2015  26531.701000
# Ireland            Ireland     13             1  2014  23344.576000
# Ireland            Ireland     13             1  2017  23561.025000
# Ireland            Ireland     13             1  2018  22860.332000
# UK                      UK      8             2  2018  11156.975000
# UK                      UK      8             2  2014  11618.781000
# UK                      UK      8             2  2017  11533.179000
# UK                      UK      8             2  2016  11958.910000
# UK                      UK      8             2  2015  11893.599000
# UK                      UK      8             2  2013  12047.682000
# South Africa  South Africa      1             3  2013  29156.277000
# ...

# %%
# dropping 1-20 to visualise expenditure in the lowest ranking countries 
dfexpend4 = dfexpend4.drop("Ireland")
dfexpend4 = dfexpend4.drop("UK")
dfexpend4 = dfexpend4.drop("South Africa")
dfexpend4 = dfexpend4.drop("Japan")
dfexpend4 = dfexpend4.drop("Estonia")
dfexpend4 = dfexpend4.drop("Croatia")
dfexpend4 = dfexpend4.drop("France")
dfexpend4 = dfexpend4.drop("Latvia")
dfexpend4 = dfexpend4.drop("Serbia")
dfexpend4 = dfexpend4.drop("Switzerland")
dfexpend4 = dfexpend4.drop("Poland")
dfexpend4 = dfexpend4.drop("Romania")
dfexpend4 = dfexpend4.drop("Bulgaria")
dfexpend4 = dfexpend4.drop("Slovakia")
dfexpend4 = dfexpend4.drop("Slovenia")
dfexpend4 = dfexpend4.drop("Lithuania")
dfexpend4 = dfexpend4.drop("Netherlands")
dfexpend4 = dfexpend4.drop("Finland")
dfexpend4 = dfexpend4.drop("Belgium")
dfexpend4 = dfexpend4.drop("Russia")
dfexpend4
# Out:
#              Country  order  order_expend  year    countpop    costpop  \
# Country2
# Mexico        Mexico     27            21  2018  340.297390  12.147749
# Mexico        Mexico     27            21  2016  248.685670   8.328386
# Mexico        Mexico     27            21  2015  229.997600   6.881766
# Mexico        Mexico     27            21  2014  120.510370   4.041606
# Mexico        Mexico     27            21  2017  291.958740  10.562840
# Mexico        Mexico     27            21  2013  124.442570   4.309562
# Canada        Canada     18            22  2013  162.050490  16.989761
# Canada        Canada     18            22  2014  129.219850  10.700915
# Canada        Canada     18            22  2018  177.443510   3.917128
# Canada        Canada     18            22  2015  108.180540   7.090487
# Canada        Canada     18            22  2016   63.450363   2.566556
# Canada        Canada     18            22  2017   83.843773   2.191262
# ...

# %%
# this graphs the public expenditure in countries in the lowest ranks  
fig8 = sns.lineplot(data=dfexpend4, 
                    x='year', y='costpop', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("Public expenditure (£) per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig8.png')
fig8

# %% [markdown]
# # BY FORMULATIONS

# %% [markdown]
# # TABLETS - counts

# %%
dftab = pd.read_csv("/Users/georgiarichards/Desktop/Python/OTC/otc_tabs.csv")
dftab
# Out:
#           Country      Country2  order  year      countpop      costpop  \
# 0    South Africa  South Africa      1  2015  31312.934000  1050.480700
# 1    South Africa  South Africa      1  2016  30976.785000  1348.794400
# 2    South Africa  South Africa      1  2017  33833.098000  1603.809100
# 3    South Africa  South Africa      1  2018  37775.301000  1637.599900
# 4    South Africa  South Africa      1  2013  29156.277000  1113.423000
# 5    South Africa  South Africa      1  2014  30092.656000  1085.042600
# 6          Serbia        Serbia      2  2014   9106.990200   651.231140
# 7          Serbia        Serbia      2  2013   8282.654300   627.275570
# 8          Serbia        Serbia      2  2015   8759.379900   597.519960
# 9          Serbia        Serbia      2  2018   7920.856000   794.197570
# 10         Serbia        Serbia      2  2017   8075.436000   765.312740
# 11         Serbia        Serbia      2  2016   8204.400400   663.929440
# ...

# %%
# drop countries that don't sell tablets 
dftab = dftab.set_index("Country2")
dftab = dftab.drop("Italy")
dftab = dftab.drop("Netherlands")
dftab = dftab.drop("Mexico")
dftab = dftab.drop("Greece")
dftab = dftab.drop("USA")
dftab = dftab.drop("Finland")
dftab = dftab.drop("Argentina")
dftab
# Out:
#                    Country  order  year      countpop      costpop  \
# Country2
# South Africa  South Africa      1  2015  31312.934000  1050.480700
# South Africa  South Africa      1  2016  30976.785000  1348.794400
# South Africa  South Africa      1  2017  33833.098000  1603.809100
# South Africa  South Africa      1  2018  37775.301000  1637.599900
# South Africa  South Africa      1  2013  29156.277000  1113.423000
# South Africa  South Africa      1  2014  30092.656000  1085.042600
# Serbia              Serbia      2  2014   9106.990200   651.231140
# Serbia              Serbia      2  2013   8282.654300   627.275570
# Serbia              Serbia      2  2015   8759.379900   597.519960
# Serbia              Serbia      2  2018   7920.856000   794.197570
# Serbia              Serbia      2  2017   8075.436000   765.312740
# Serbia              Serbia      2  2016   8204.400400   663.929440
# Croatia            Croatia      3  2014   7229.843800  1138.708400
# ...

# %%
# graphing sales for countries ranked 11-20 for all counts 
fig9 = sns.lineplot(data=dftab, 
                    x='year', y='countpoptab', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of tablets per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig9.png')
fig9
# redo graph with diff colors for countries after 10 (or use different markers??)

# %% [markdown]
# # TABLETS - expenditure, £

# %%
# graphing sales for countries ranked 11-20 for all counts 
fig10 = sns.lineplot(data=dftab, 
                    x='year', y='costpoptab', 
                    hue='Country',
                    palette="bright",
                    marker="o") 
plt.xlabel(" ")
plt.ylabel("No. of tablets per 1,000 population", fontsize= 12)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.savefig('fig10.png')
fig10

# %%
# find a way to sort on panadas or reorder & reload data... 
dftab = pd.read_csv("/Users/georgiarichards/Desktop/Python/OTC/otc_tabs.csv")
dftab

# %%
# Importing data by specifying the Index & graphing using the index 
df1 = pd.read_csv("/Users/georgiarichards/Desktop/Python/OTC/otc_sales_long.csv", index_col='Country')
df1
# Out:
#              year      countpop      costpop  countpopcach  costpopcach  \
# Country
# Argentina    2013      0.263015     0.005568           NaN          NaN
# Argentina    2014      0.435909     0.008788           NaN          NaN
# Argentina    2015      0.000000     0.000000           NaN          NaN
# Argentina    2016      0.000000     0.000000           NaN          NaN
# Argentina    2017      0.000000     0.000000           NaN          NaN
# Argentina    2018      0.000000     0.000000           NaN          NaN
# Belgium      2013   2239.108600   122.667980      0.003226     0.000627
# Belgium      2014    195.365140    29.909206      0.000714     0.000268
# Belgium      2015    163.799180    21.805014      0.000000     0.000000
# Belgium      2016    156.658190    23.514259      0.000000     0.000000
# Belgium      2017    144.113160    22.295954      0.000000     0.000000
# Belgium      2018    144.760160    22.238459      0.000000     0.000000
# ...

# %%
df1.loc['UK'].plot.line(x='year', y='countpop')
plt.ylabel("No. of items sold per 1,000 pop")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [UK] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1c4afed4d353> in <module>
# ----> 1 df1.loc['UK'].plot.line(x='year', y='countpop')
#       2 plt.ylabel("No. of items sold per 1,000 pop")
#
# ...
